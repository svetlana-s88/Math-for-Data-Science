# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# подключаем  датасет
df = pd.read_csv('C:/Users/user/Downloads/tvmarketing.csv')
x = np.array(df['TV']).ravel()
y = np.array(df['Sales'])

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of         TV  Sales
# 0    230.1   22.1
# 1     44.5   10.4
# 2     17.2    9.3
# 3    151.5   18.5
# 4    180.8   12.9
# ..     ...    ...
# 195   38.2    7.6
# 196   94.2    9.7
# 197  177.0   12.8
# 198  283.6   25.5
# 199  232.1   13.4
#
# [200 rows x 2 columns]>

# %%
plt.figure(figsize = (8, 5))
sns.scatterplot(data = df, x='TV', y ='Sales', color= 'blue')
plt.title('Зависимость продаж от рекламы на ТВ')
plt.xlabel('Затраты на рекламу(в тыс долл)')
plt.ylabel('Продажи(в млн долл)')
plt.grid(True)
plt.show()
